# %%
import pandas as pd
import duckdb
from pathlib import Path
import os
import io

POPISY = Path("POPISY")
DATA = Path("DATA")
CISELNIKY = Path("ČÍSELNÍKY")


def human_readable(df: pd.DataFrame, map_file: str) -> str:
    import json

    map_path = POPISY / map_file

    with open(map_path, "r") as file:
        mapping = json.loads(file.read())
        return df.rename(columns=mapping)


args = {"sep": ";", "encoding": "cp1250"}

material = pd.read_csv(DATA / "VYK_23" / "vyk_23_material_new.csv", **args)
display(material.head())
display(human_readable(material, "vyk_material.json").head())
vykony = pd.read_csv(DATA / "VYK_23" / "vyk_23_vykony_new.csv", **args)
display(vykony.head())
display(human_readable(vykony, "vyk_vykony.json").head())

vykpac = pd.read_csv(DATA / "VYK_23" / "vyk_23_vykpac_new.csv", **args)
display(vykpac.head())
display(human_readable(vykpac, "vyk_vykpac.json").head())
# Out:
#    SERIAL  CDOKL             DATUM  TYP      KOD  ZVL  LOKALIZACE  ODDELENI  \
# 0     262  12590  25.01.2023 00:00    1  0000516    0         NaN     10626
# 1     263  12590  25.01.2023 00:00    1  0093746    0         NaN     10626
# 2     264  12590  25.01.2023 00:00    3  0048092    0         NaN     10626
# 3     349  14330  07.01.2023 00:00    1  0000516    0         NaN     10626
# 4     350  14330  07.01.2023 00:00    1  0093746    0         NaN     10626
#
#    MNOZSTVI CENAUZIV     CENA  SERIALCDB   CISPAC
# 0       0.1    0.000    0.240        262  1570034
# 1       0.2    0.000   23.460        263  1570034
# 2       1.0    0.000  154.000        264  1570034
# 3       0.1    0.000    0.240        349  2104772
# 4       0.1    0.000   11.730        350  2104772
#    POŘADOVÉ ČÍSLO  ČÍSLO DOKLADU     DATUM ZÁZNAMU  TYP ÚČTOVANÉ POLOŽKY  \
# 0             262          12590  25.01.2023 00:00                     1
# 1             263          12590  25.01.2023 00:00                     1
# 2             264          12590  25.01.2023 00:00                     3
# 3             349          14330  07.01.2023 00:00                     1
# 4             350          14330  07.01.2023 00:00                     1
#
#   KÓD POLOŽKY  ZVÝŠENÁ ÚHRADA  LOKALIZACE  ODDĚLENÍ  MNOŽSTVÍ  \
# 0     0000516               0         NaN     10626       0.1
# 1     0093746               0         NaN     10626       0.2
# 2     0048092               0         NaN     10626       1.0
# 3     0000516               0         NaN     10626       0.1
# 4     0093746               0         NaN     10626       0.1
#
#   UŽIVATELSKÁ CENA     CENA  SÉRIOVÉ ČÍSLO CENTRÁLNÍ DATABÁZE  ČÍSLO PACIENTA
# 0            0.000    0.240                               262         1570034
# 1            0.000   23.460                               263         1570034
# 2            0.000  154.000                               264         1570034
# 3            0.000    0.240                               349         2104772
# 4            0.000   11.730                               350         2104772
#    SERIAL  CDOKL             DATUM    KOD  ODBORNOST    DG  LOKALIZACE  \
# 0    6198   6384  17.01.2023 00:00  42022      402.0  C719         NaN
# 1    6199   6384  17.01.2023 00:00   9543      402.0  C719         NaN
# 2    6200   6386  18.01.2023 00:00   9511      402.0  C719         NaN
# 3    6317   6442  17.01.2023 00:00  42022      402.0   N47         NaN
# 4    6318   6442  17.01.2023 00:00   9543      402.0   N47         NaN
#
#    ODDELENI  CAS  MNOZSTVI     BODY  CENAMAT  CENAUZIV     CENA  SERIALCDB  \
# 0     10626  NaN         1  435.000      0.0       0.0  391.500     6198.0
# 1     10626  NaN         1    0.000      0.0       0.0    0.000     6199.0
# 2     10626  NaN         1   45.000      0.0       0.0   40.500     6200.0
# 3     10837  NaN         1  435.000      0.0       0.0  391.500     6317.0
# 4     10837  NaN         1    0.000      0.0       0.0    0.000     6318.0
#
#     CISPAC
# 0   213292
# 1   213292
# 2   213292
# 3  1892691
# 4  1892691
#    POŘADOVÉ ČÍSLO  ČÍSLO DOKLADU     DATUM ZÁZNAMU  KÓD VÝKONU  ODBORNOST  \
# 0            6198           6384  17.01.2023 00:00       42022      402.0
# 1            6199           6384  17.01.2023 00:00        9543      402.0
# 2            6200           6386  18.01.2023 00:00        9511      402.0
# 3            6317           6442  17.01.2023 00:00       42022      402.0
# 4            6318           6442  17.01.2023 00:00        9543      402.0
#
#   DIAGNÓZA  LOKALIZACE  ODDĚLENÍ  ČAS  MNOŽSTVÍ BODY ZA VÝKON  CENA   \
# 0     C719         NaN     10626  NaN         1       435.000    0.0
# 1     C719         NaN     10626  NaN         1         0.000    0.0
# 2     C719         NaN     10626  NaN         1        45.000    0.0
# 3      N47         NaN     10837  NaN         1       435.000    0.0
# 4      N47         NaN     10837  NaN         1         0.000    0.0
#
#    UŽIVATELSKÁ CENA CELKOVÁ CENA  SERIALCDB  ČÍSLO PACIENTA
# 0               0.0      391.500     6198.0          213292
# 1               0.0        0.000     6199.0          213292
# 2               0.0       40.500     6200.0          213292
# 3               0.0      391.500     6317.0         1892691
# 4               0.0        0.000     6318.0         1892691
# /var/folders/6j/kydy068d34z7rl2sx3hwb8gh0000gn/T/ipykernel_63605/4141076646.py:31: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   vykpac = pd.read_csv(DATA / "VYK_23" / "vyk_23_vykpac_new.csv", **args)
#    CDOKL  POJCDOKL  CYEAR    CCHOR1   CIDENT   CISPAC  POJISTOVNA  \
# 0   6384      6384   2023  45968574  7290224   213292         207
# 1   6386      6386   2023  45980138  7290261   213292         207
# 2   6442      6442   2023  45964330      NaN  1892691         201
# 3   6630      6630   2023  46044195      NaN   209185         207
# 4   6790      6790   2023  45907288  7290108  1640608         209
#
#   CISLOPOJISTKY  PRIPOJISTENI  POHLAVI  ... OBDOBIDOKL  PLATCE  TYPSUBJEKTU  \
# 0     2230734.0             0        0  ...   20230101       0            5
# 1     2230734.0             0        0  ...   20230101       0            5
# 2           NaN             0        0  ...   20230101       0            5
# 3           NaN             0        0  ...   20230101       0            5
# 4     8082470.0             0        0  ...   20230101       0            5
#
#    KODSUBJEKTU  SYSTEMUCETZALOZIL  SOURCESYSTEM CISPOJUZIS UNISFAKT1  \
# 0        10626                  3             3        NaN         0
# 1        10626                  3             3        NaN         0
# 2        10837                219           219        NaN         0
# 3        10370                  3             3        NaN         0
# 4        10626                  3             3        NaN         0
#
#      DATODSOUHLUCET KDOODSOUHLUCET
# 0  17.01.2023 18:37            NaN
# 1  18.01.2023 15:08            NaN
# 2  20.01.2023 09:51            NaN
# 3  26.01.2023 11:38            NaN
# 4  09.01.2023 23:50            NaN
#
# [5 rows x 110 columns]
#    ČÍSLO DOKLADU  ČÍSLO DOKLADU PRO POJIŠŤOVNU  ROK Z POČÍTADLA  \
# 0           6384                          6384             2023
# 1           6386                          6386             2023
# 2           6442                          6442             2023
# 3           6630                          6630             2023
# 4           6790                          6790             2023
#
#    ČÍSLO PŘÍJMU V CHOROBOPISE ČÍSLO CHOROBOPISU INTERNÍ  ČÍSLO PACIENTA  \
# 0                    45968574                   7290224          213292
# 1                    45980138                   7290261          213292
# 2                    45964330                       NaN         1892691
# 3                    46044195                       NaN          209185
# 4                    45907288                   7290108         1640608
#
#    POJIŠTOVNA ČÍSLO POJISTKY  PŘIPOJIŠTĚNÍ  POHLAVÍ - 0 MUŽ, 1 -ŽENA  ...  \
# 0         207      2230734.0             0                         0  ...
# 1         207      2230734.0             0                         0  ...
# 2         201            NaN             0                         0  ...
# 3         207            NaN             0                         0  ...
# 4         209      8082470.0             0                         0  ...
#
#      OBDOBÍ  EXTERNÍ SUBJEKT  TYP SUBJEKTU  KÓD SUBJEKTU  \
# 0  20230101                0             5         10626
# 1  20230101                0             5         10626
# 2  20230101                0             5         10837
# 3  20230101                0             5         10370
# 4  20230101                0             5         10626
#
#    SYSTÉM, KTERÝ ÚČET ZALOŽIL  SOURCESYSTEM ČÍSLO POJIŠTĚNCE   \
# 0                           3             3               NaN
# 1                           3             3               NaN
# 2                         219           219               NaN
# 3                           3             3               NaN
# 4                           3             3               NaN
#
#   ČÍSLO FAKTURY UNIS  DATUM ODOUHLASENÍ ÚČTU KDO ODSOUHLASIL
# 0                  0        17.01.2023 18:37             NaN
# 1                  0        18.01.2023 15:08             NaN
# 2                  0        20.01.2023 09:51             NaN
# 3                  0        26.01.2023 11:38             NaN
# 4                  0        09.01.2023 23:50             NaN
#
# [5 rows x 110 columns]

# %%
import re
from pathlib import Path
from typing import TypedDict


class AmbulanceEvent(TypedDict):
    seq: str
    customer: str
    sse: str
    ambnum: str
    payload: str


def get_event(path: Path, *, prefix: str) -> list[AmbulanceEvent]:
    chunks: list[AmbulanceEvent] = []
    with open(path, "r", encoding="cp1250") as file:
        buffer: str = ""
        last_match: list[str] = []

        for line in file:
            if line.strip().startswith("===") and line.count("/") == 2:
                match = re.match(
                    r"=== (\d+)\. (\d+) / ([a-zA-Z0-9]{10}) / (\d+)", line.strip()
                )
                if last_match:
                    _, serial, sse, ambnum = last_match
                    chunks.append(
                        {
                            "FILE": os.path.splitext(path.name)[0].split(prefix)[1],
                            "SERIAL": int(serial),
                            "RC": sse,
                            "AMBNUM": int(ambnum),
                            "CONTENT": buffer,
                        }
                    )

                buffer = ""
                last_match = match.groups()
                continue

            buffer += line
    return chunks


zpravy = []
for file in sorted((DATA / "PAC" / "AMBULATNÍ ZPRÁVA" / "2023").glob("*.Txt")):
    zpravy.extend(get_event(file, prefix="Events_"))

zpravy = pd.DataFrame(zpravy)
display(zpravy.head())

leave = []
for file in sorted((DATA / "PAC" / "PROPOUŠTĚCÍ ZPRÁVA" / "2023").glob("*.Txt")):
    leave.extend(get_event(file, prefix="ZavZprav_"))
    
leave = pd.DataFrame(leave)
display(leave.head())
# Out:
# Task exception was never retrieved
# future: <Task finished name='Task-45' coro=<Server.serve() done, defined at /Users/duongtat/Downloads/023_RAKATHON/.venv/lib/python3.13/site-packages/uvicorn/server.py:68> exception=KeyboardInterrupt()>
# Traceback (most recent call last):
#   File "/Users/duongtat/Downloads/023_RAKATHON/.venv/lib/python3.13/site-packages/uvicorn/main.py", line 579, in run
#     server.run()
#     ~~~~~~~~~~^^
#   File "/Users/duongtat/Downloads/023_RAKATHON/.venv/lib/python3.13/site-packages/uvicorn/server.py", line 66, in run
#     return asyncio.run(self.serve(sockets=sockets))
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/duongtat/Downloads/023_RAKATHON/.venv/lib/python3.13/site-packages/nest_asyncio.py", line 30, in run
#     return loop.run_until_complete(task)
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/Users/duongtat/Downloads/023_RAKATHON/.venv/lib/python3.13/site-packages/nest_asyncio.py", line 92, in run_until_complete
#     self._run_once()
#     ~~~~~~~~~~~~~~^^
#   File "/Users/duongtat/Downloads/023_RAKATHON/.venv/lib/python3.13/site-packages/nest_asyncio.py", line 133, in _run_once
#     handle._run()
#     ~~~~~~~~~~~^^
#   File "/opt/homebrew/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/lib/python3.13/asyncio/events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/lib/python3.13/asyncio/tasks.py", line 386, in __wakeup
#     self.__step()
#     ~~~~~~~~~~~^^
#   File "/opt/homebrew/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/lib/python3.13/asyncio/tasks.py", line 293, in __step
#     self.__step_run_and_handle_result(exc)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^
#   File "/opt/homebrew/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/lib/python3.13/asyncio/tasks.py", line 304, in __step_run_and_handle_result
#     result = coro.send(None)
#   File "/Users/duongtat/Downloads/023_RAKATHON/.venv/lib/python3.13/site-packages/uvicorn/server.py", line 69, in serve
#     with self.capture_signals():
#          ~~~~~~~~~~~~~~~~~~~~^^
#   File "/opt/homebrew/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/lib/python3.13/contextlib.py", line 148, in __exit__
#     next(self.gen)
#     ~~~~^^^^^^^^^^
#   File "/Users/duongtat/Downloads/023_RAKATHON/.venv/lib/python3.13/site-packages/uvicorn/server.py", line 330, in capture_signals
#     signal.raise_signal(captured_signal)
#     ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Task exception was never retrieved
# future: <Task finished name='Task-62' coro=<Server.serve() done, defined at /Users/duongtat/Downloads/023_RAKATHON/.venv/lib/python3.13/site-packages/uvicorn/server.py:68> exception=KeyboardInterrupt()>
# Traceback (most recent call last):
#   File "/Users/duongtat/Downloads/023_RAKATHON/.venv/lib/python3.13/site-packages/uvicorn/main.py", line 579, in run
#     server.run()
#     ~~~~~~~~~~^^
#   File "/Users/duongtat/Downloads/023_RAKATHON/.venv/lib/python3.13/site-packages/uvicorn/server.py", line 66, in run
#     return asyncio.run(self.serve(sockets=sockets))
#            ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/duongtat/Downloads/023_RAKATHON/.venv/lib/python3.13/site-packages/nest_asyncio.py", line 30, in run
#     return loop.run_until_complete(task)
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/Users/duongtat/Downloads/023_RAKATHON/.venv/lib/python3.13/site-packages/nest_asyncio.py", line 92, in run_until_complete
#     self._run_once()
#     ~~~~~~~~~~~~~~^^
#   File "/Users/duongtat/Downloads/023_RAKATHON/.venv/lib/python3.13/site-packages/nest_asyncio.py", line 133, in _run_once
#     handle._run()
#     ~~~~~~~~~~~^^
#   File "/opt/homebrew/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/lib/python3.13/asyncio/events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/lib/python3.13/asyncio/tasks.py", line 386, in __wakeup
#     self.__step()
#     ~~~~~~~~~~~^^
#   File "/opt/homebrew/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/lib/python3.13/asyncio/tasks.py", line 293, in __step
#     self.__step_run_and_handle_result(exc)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^
#   File "/opt/homebrew/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/lib/python3.13/asyncio/tasks.py", line 304, in __step_run_and_handle_result
#     result = coro.send(None)
#   File "/Users/duongtat/Downloads/023_RAKATHON/.venv/lib/python3.13/site-packages/uvicorn/server.py", line 69, in serve
#     with self.capture_signals():
#          ~~~~~~~~~~~~~~~~~~~~^^
#   File "/opt/homebrew/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/lib/python3.13/contextlib.py", line 148, in __exit__
#     next(self.gen)
#     ~~~~^^^^^^^^^^
#   File "/Users/duongtat/Downloads/023_RAKATHON/.venv/lib/python3.13/site-packages/uvicorn/server.py", line 330, in capture_signals
#     signal.raise_signal(captured_signal)
#     ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#       FILE   SERIAL          RC  AMBNUM  \
# 0  2023_01  1430073  640XXXXXXX   53835
# 1  2023_01  1430084  716XXXXXXX   58891
# 2  2023_01  1387088  660XXXXXXX   55647
# 3  2023_01  1423870  685XXXXXXX   26033
# 4  2023_01  1399503  660XXXXXXX   50413
#
#                                              CONTENT
# 0  MUDr. Pajdlhauser Roman\ndomluva na hosital CH...
# 1  MUDr. Hanušová Zuzana\nC19 \nPravidelná kontro...
# 2  MUDr. Urie Petr\nC051 \nVýška: 170cm    Váha: ...
# 3  MUDr. Nohejlová  Medková Anna\nC493 \nC810 \n3...
# 4  MUDr. Urie Petr\nC162 \nVýška: 165cm     Váha:...
#       FILE  SERIAL          RC  AMBNUM  \
# 0  2023_01  275828  665XXXXXXX   59047
# 1  2023_01  275913  835XXXXXXX   50775
# 2  2023_01  276472  560XXXXXXX    8460
# 3  2023_01  276172  990XXXXXXX   59522
# 4  2023_01  277031  560XXXXXXX   54409
#
#                                              CONTENT
# 0  DŮVOD PŘIJETÍ K HOSPITALIZACI: \nPacientku při...
# 1  DŮVOD PŘIJETÍ K HOSPITALIZACI: \npřijata k apl...
# 2  DŮVOD PŘIJETÍ K HOSPITALIZACI: \npřijat k apli...
# 3  DŮVOD PŘIJETÍ K HOSPITALIZACI: \nzpomalené psy...
# 4  DŮVOD PŘIJETÍ K HOSPITALIZACI: \nPacient přija...

# %%
def read_txtevent_file(path: Path, *, with_header: bool = False) -> str:
    with open(path, "r", encoding="cp1250") as file:
        file_prefix = path.name.split(".")[0].split("TXTEVENT_")[1]
        return "".join(
            [
                (file_prefix if enum > 0 else "FILE") + ";" + line
                for enum, line in enumerate(file)
                if with_header or enum > 0
            ]
        )


lines = ""
for i, map_file in enumerate(sorted((DATA / "PAC" / "DOKUMENTACE" / "2023").glob("*.csv"))):
    lines += read_txtevent_file(map_file, with_header=i == 0)

dokumentace = pd.read_csv(io.StringIO(lines), sep=";")
dokumentace.head()
# Out:
#       FILE  POR  UDALOST_CISLO UDALOST     DATUM  ODDEL  LEKAR  \
# 0  2023_01    1              2    RATO  20230125  10248  22217
# 1  2023_01    2              5    RATP  20230125  10370  93786
# 2  2023_01    3              5    RATP  20230116  10370  22298
# 3  2023_01    4              5    RATP  20230104  10452  22422
# 4  2023_01    5              5    RATP  20230105  10370  22298
#
#          DATUM_CAS    DIAGNOZA         DATUM_OD  ... HODNOCENI  JMENO  \
# 0  20230125_101800         NaN  00010101_000000  ...         0    NaN
# 1  20230125_102500         C19  00010101_000000  ...         0    NaN
# 2  20230116_110000        C051  00010101_000000  ...         0    NaN
# 3  20230104_112500  C493, C810  00010101_000000  ...         0    NaN
# 4  20230105_110000        C162  00010101_000000  ...         0    NaN
#
#            RC  AMBNUM   CISPAC    PSC  DATUM_NAR VEKR  VEKM  VEKD
# 0  640XXXXXXX   53835  2124171  11000      10101   58     8    14
# 1  716XXXXXXX   58891  2259382  28601      10101   51     3    14
# 2  660XXXXXXX   55647  2193508  27201      10101   56     9    29
# 3  685XXXXXXX   26033   508766  16000      10101   54     6    19
# 4  660XXXXXXX   50413   298937  10000      10101   56    10    13
#
# [5 rows x 22 columns]

# %%
vazby = pd.read_csv(DATA / "PAC" / "events_date_2023.csv", sep=";")
vazby.head()
# Out:
#     SERIAL  AMBNUM             DATFR  DEPARTM    WHO
# 0  1387088   55647  16.01.2023 11:00    10370  22298
# 1  1399503   50413  05.01.2023 11:00    10370  22298
# 2  1399525   56795  12.01.2023 09:45    10370  22298
# 3  1407661   14010  17.01.2023 06:42    10370  22161
# 4  1408001   23454  26.01.2023 09:12    10452  22161

# %%
import datetime

item_zpravy = zpravy.iloc[23]
print(item_zpravy)

item_vazby = vazby[
    (vazby["SERIAL"] == item_zpravy["SERIAL"])
    & (vazby["AMBNUM"] == item_zpravy["AMBNUM"])
]
## Jsem schopen přiřadit datum pro jednotlivé ambulantní zprávy
display(item_vazby)

item_vazby_dokumentace_date = datetime.datetime.strftime(
    pd.to_datetime(item_vazby["DATFR"], format="%d.%m.%Y %H:%M").squeeze(),
    "%Y%m%d_%H%M00",
)
item_vazby_vyk_date = datetime.datetime.strftime(
    pd.to_datetime(item_vazby["DATFR"], format="%d.%m.%Y %H:%M").squeeze(),
    "%d.%m.%Y 00:00",
)
display(item_vazby_dokumentace_date)

item_dokumentace = dokumentace[
    (dokumentace["AMBNUM"] == item_zpravy["AMBNUM"])
    & (dokumentace["DATUM_CAS"] == item_vazby_dokumentace_date)
]
display(item_dokumentace)

cispac = next(x for x in item_dokumentace["CISPAC"])

display(material[(material["CISPAC"] == cispac) & (material["DATUM"] == item_vazby_vyk_date)])
display(vykony[(vykony["CISPAC"] == cispac) & (vykony["DATUM"] == item_vazby_vyk_date)])

# Tohle jsou jen všechny účty pro daného pacienta
vykpac[vykpac["CISPAC"] == cispac];
# Out:
# MUDr. Bulová Alena
# C20
# 15. cyklus FOLFOX  (red. o 25% pro hematolog. toxicitu) via PICC-PORT od 02.01.2023
#
# 1/ Dithiaden 1amp + 200ml HCT + 100ml G5% / 10min
# 2/ F1/1 100ml +1amp.Quamatel+2amp Dexamed + 1amp Palonosetron + 1amp Degan i.v. na 10min.
# 3/ 500ml 5%G + Oxaliplatina 82 mg i.v. / 2 hod
# 4/ Calcium folinat 380mg+F1/1 500ml i.v. na 2 hod.
# ------------ Calcium folnat+ Oxaliplatina kapat dohromady ------------
# 5/ 5-Fluorouracil 384 mg +F1/1 20ml i.v. bolus 3min.
# 6/ 5-Fluorouracil 2304 mg + Baxter  i.v. na 46hod.
#
# + Rp Pelgraz
#
# Medikace:
# chronická medikace,
# Granegis 1mg tbl. 1-0-1 při nevolnosti ev. přidat  Degan tbl. 1-1-1 při nevolnosti
# - 05.01.2023 aplikuje podkožně Pelgraz
#
# Doporučení:
# - 04.01.2023 ukončení Baxter na Stacionáři, uzel C, 3. patro
# - 13.01.2023 odběry (KO+diff, bio) 7-8hod v Onkologické ambulanci (3. patro D), o výsledky pacient zavolá  po 12:00 hod na 22443 4786/4745
# - 16.01.2023 aplikace dalšího cyklu FOLFOX na Stacionáři Onkologické kliniky (3C)
# - pravidelné kontroly v onkologické ambulanci (3D), tel. k objednání 224434760
#      SERIAL  AMBNUM             DATFR  DEPARTM    WHO
# 59  1422607   50906  02.01.2023 07:00    10552  22475
# '20230102_070000'
#        FILE  POR  UDALOST_CISLO UDALOST     DATUM  ODDEL  LEKAR  \
# 23  2023_01   24              6    RATS  20230102  10552  22475
#
#           DATUM_CAS DIAGNOZA         DATUM_OD  ... HODNOCENI  JMENO  \
# 23  20230102_070000      C20  00010101_000000  ...         0    NaN
#
#             RC  AMBNUM  CISPAC    PSC  DATUM_NAR VEKR  VEKM  VEKD
# 23  595XXXXXXX   50906  711134  26601      10101   63     3    19
#
# [1 rows x 22 columns]
#       SERIAL   CDOKL             DATUM  TYP      KOD  ZVL  LOKALIZACE  \
# 5326   23101  289532  02.01.2023 00:00    1  0084090    0         NaN
# 5327   23102  289532  02.01.2023 00:00    1  0209360    0         NaN
# 5328   23103  289532  02.01.2023 00:00    1  0093105    0         NaN
# 5329   23104  289532  02.01.2023 00:00    1  0144406    0         NaN
# 5330   23105  289532  02.01.2023 00:00    1  0004071    0         NaN
# 5331   23106  289532  02.01.2023 00:00    1  0124067    0         NaN
# 5332   23107  289532  02.01.2023 00:00    1  0082952    0         NaN
# 5333   23108  289532  02.01.2023 00:00    1  0242251    0         NaN
# 5334   23109  289532  02.01.2023 00:00    1  0132105    0         NaN
# 5335   23110  289532  02.01.2023 00:00    1  0132101    0         NaN
# 5336   23111  289532  02.01.2023 00:00    3  0049741    0         NaN
# 5337   23112  289532  02.01.2023 00:00    3  0049487    0         NaN
# 5338   23113  289532  02.01.2023 00:00    3  0194437    0         NaN
# 5339   23114  289532  02.01.2023 00:00    3  0194432    0         NaN
#
#       ODDELENI  MNOZSTVI CENAUZIV       CENA  SERIALCDB  CISPAC
# 5326     10552      0.20    0.000     17.030      23101  711134
# 5327     10552      1.00    0.000    148.460      23102  711134
# 5328     10552      0.02    0.000      5.500      23103  711134
# 5329     10552      1.00    0.000  1 431.360      23104  711134
# 5330     10552      0.10    0.000     20.540      23105  711134
# 5331     10552      2.00    0.000     97.480      23106  711134
# 5332     10552      0.20    0.000     36.430      23107  711134
# 5333     10552      3.00    0.000    219.450      23108  711134
# 5334     10552      1.00    0.000    618.480      23109  711134
# 5335     10552      1.00    0.000    206.490      23110  711134
# 5336     10552      1.00    0.000    105.000      23111  711134
# 5337     10552      1.00    0.000    867.000      23112  711134
# 5338     10552      1.00    0.000    187.580      23113  711134
# 5339     10552      1.00    0.000     62.650      23114  711134
#        SERIAL   CDOKL             DATUM    KOD  ODBORNOST   DG  LOKALIZACE  \
# 10651  623530  289532  02.01.2023 00:00  42022      402.0  C20         NaN
# 10652  623531  289532  02.01.2023 00:00   9543      402.0  C20         NaN
# 10653  623532  289532  02.01.2023 00:00   9541      402.0  C20         NaN
# 10654  623533  289532  02.01.2023 00:00   9223      402.0  C20         NaN
# 10655  623534  289532  02.01.2023 00:00  42520      402.0  C20         NaN
# 10656  623535  289532  02.01.2023 00:00  42050      402.0  C20         NaN
#
#        ODDELENI  CAS  MNOZSTVI     BODY  CENAMAT  CENAUZIV     CENA  \
# 10651     10552  NaN         1  435.000      0.0       0.0  391.500
# 10652     10552  NaN         1    0.000      0.0       0.0    0.000
# 10653     10552  NaN         1   97.000      0.0       0.0   87.300
# 10654     10552  NaN         1  153.000      0.0       0.0  137.700
# 10655     10552  NaN         2  570.000      0.0       0.0  513.000
# 10656     10552  NaN         1  946.000      0.0       0.0  851.400
#
#        SERIALCDB  CISPAC
# 10651   623530.0  711134
# 10652   623531.0  711134
# 10653   623532.0  711134
# 10654   623533.0  711134
# 10655   623534.0  711134
# 10656   623535.0  711134

# %%
from fastapi import FastAPI, HTTPException
from pydantic import BaseModel
import pandas as pd
import datetime
import nest_asyncio
import uvicorn
from fastapi.middleware.cors import CORSMiddleware

app = FastAPI()

app.add_middleware(
    CORSMiddleware,
    allow_origins=["*"],  # Allows all origins
    allow_credentials=True,
    allow_methods=["*"],  # Allows all methods
    allow_headers=["*"],  # Allows all headers
)


class PatientDataRequest(BaseModel):
    iloc: int


@app.get("/get_patient_data/{iloc}")
async def get_patient_data(iloc: int):
    try:
        item_zpravy = zpravy.iloc[iloc]
    except IndexError:
        raise HTTPException(status_code=404, detail="Patient data not found")

    item_vazby = vazby[
        (vazby["SERIAL"] == item_zpravy["SERIAL"])
        & (vazby["AMBNUM"] == item_zpravy["AMBNUM"])
    ]

    item_vazby_dokumentace_date = datetime.datetime.strftime(
        pd.to_datetime(item_vazby["DATFR"], format="%d.%m.%Y %H:%M").squeeze(),
        "%Y%m%d_%H%M00",
    )
    item_vazby_vyk_date = datetime.datetime.strftime(
        pd.to_datetime(item_vazby["DATFR"], format="%d.%m.%Y %H:%M").squeeze(),
        "%d.%m.%Y 00:00",
    )

    item_dokumentace = dokumentace[
        (dokumentace["AMBNUM"] == item_zpravy["AMBNUM"])
        & (dokumentace["DATUM_CAS"] == item_vazby_dokumentace_date)
    ]

    cispac = next(x for x in item_dokumentace["CISPAC"])

    material_data = material[
        (material["CISPAC"] == cispac) & (material["DATUM"] == item_vazby_vyk_date)
    ]
    vykony_data = vykony[
        (vykony["CISPAC"] == cispac) & (vykony["DATUM"] == item_vazby_vyk_date)
    ]
    vykpac_data = vykpac[vykpac["CISPAC"] == cispac]

    response = {
        "zpravy_content": item_zpravy["CONTENT"],
        "vazby": item_vazby.fillna("").to_dict(orient="records"),
        "dokumentace": item_dokumentace.fillna("").to_dict(orient="records"),
        "material": material_data.fillna("").to_dict(orient="records"),
        "vykony": vykony_data.fillna("").to_dict(orient="records"),
        "vykpac": vykpac_data.fillna("").to_dict(orient="records"),
    }

    return response


if __name__ == "__main__":
    nest_asyncio.apply()
    uvicorn.run(app, host="0.0.0.0", port=9183)
# Out:
# INFO:     Started server process [63605]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:9183 (Press CTRL+C to quit)
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [63605]
